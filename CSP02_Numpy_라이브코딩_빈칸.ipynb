# %% [markdown]
# ## [Live Coding1]
#
#  이번 실습 데이터는 1970년부터 2067년까지 매년 한국의 남성과 여성 기대수명 통계자료를 담고 있는 2차원 데이터이다.  (출처: 국가통계포털, https://kosis.kr/statHtml/statHtml.do?mode=tab&orgId=101&tblId=DT_1BPA201)
#
#  1. 데이터 확인

# %%
data = # 빈 칸 #

# %% [markdown]
# 2. 전체 기간 남자, 여자의 기대수명 평균을 구하시오.

# %% [markdown]
# 3. 2060년 이후 데이터를 구하시오.

# %%
print('연도','남자', '여자',sep='\t')
print('='*23)

# 빈 칸 #

# %% [markdown]
# 4. 남자 기대수명이 가장 큰 연도와 그때의 기대수명을 구하시오.

# %% [markdown]
# 5. 여자의 기대수명이 가장 많은 Top5 연도를 구하시오.

# %%
# 빈 칸 #

print('연도', '여자 기대수명', sep='\t')
for i in data:
  for j in top5_f:
    if i[2] == j:
      print(i[0], j, sep='\t')

# %% [markdown]
# 6. 여자 기대수명이 처음 80세 이상이 된 연도와 남자가 80세 이상이 된 해의 차이를 구하시오.

# %%
over80_m = # 빈 칸 #
over80_f = # 빈 칸 #

print(over80_m, over80_f, over80_m-over80_f)

# %% [markdown]
# 7. 각 연도별 남자와 여자의 기대수명 차이를 데이터로 보여주시오.

# %%
diff = # 빈 칸 #

print('연도', '기대수명 차이', sep='\t')
print('=='*14)

for y, d in # 빈 칸 #:
  print(y, d, sep='\t')

# %% [markdown]
# 8. 남자 기대수명 데이터 중 25%~75% 사이의 데이터를 구하시오.

# %%
per25_m = # 빈 칸 #
per75_m = # 빈 칸 #
print(per25_m, per75_m)

# 빈 칸 #
